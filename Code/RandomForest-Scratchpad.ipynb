# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer('english')

# %%
df_train = pd.read_csv('../csv/train.csv', encoding="ISO-8859-1")
df_test = pd.read_csv('../csv/test.csv', encoding="ISO-8859-1")
# df_attr = pd.read_csv('../input/attributes.csv')
df_pro_desc = pd.read_csv('../csv/product_descriptions.csv')

# %%
num_train = df_train.shape[0]

# %%
num_train
# Out:
# 74067

# %%
df_train
# Out:
#            id  product_uid                                      product_title  \
# 0           2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1           3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2           9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3          16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4          17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5          18       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 6          20       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 7          21       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8          23       100007  Lithonia Lighting Quantum 2-Light Black LED Em...
# 9          27       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 10         34       100010       Valley View Industries Metal Stakes (4-Pack)
# 11         35       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 12         37       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 13         38       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 14         48       100012  Hampton Bay Caramel Simple Weave Bamboo Rollup...
# 15         51       100013  InSinkErator SinkTop Switch Single Outlet for ...
# 16         65       100016  Sunjoy Calais 8 ft. x 5 ft. x 8 ft. Steel Tile...
# 17         69       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 18         75       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 19         81       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 20         85       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 21         88       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 22         90       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 23         92       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 24        101       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 25        105       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 26        106       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 27        113       100021  1804 Dual Spray Half Pattern 4 in Pop-Up Spray...
# 28        114       100021  1804 Dual Spray Half Pattern 4 in Pop-Up Spray...
# 29        117       100022  Samsung 4.2 cu. ft. Front Load Washer with Ste...
# ...       ...          ...                                                ...
# 74037  221398       206588  Cake Boss Decorating Tools 3-Piece Plastic Ici...
# 74038  221400       206589  Husky Universal Pass-Through Mechanics Tool Se...
# 74039  221401       206590    Crosley LaFayette Low Profile TV Stand in Black
# 74040  221404       206593  Rust-Oleum Automotive 8 oz. Special White Auto...
# 74041  221405       206594  Foremost Tides 33 in. to 35 in. x 65 in. Frame...
# 74042  221407       206596  Bali Cut-to-Size Crown 3.5 in. PVC Louver Set ...
# 74043  221408       206597  Home Fashion Technologies 14 in. x 59 in. Soli...
# 74044  221409       206598              Newport Coastal Photo Eye Replacement
# 74045  221411       206599  HYDRONIX 12 in. x 2-1/2 in. Inline Coconut Car...
# 74046  221412       206600  Worx 12 in. Ni-cd 24-Volt 3-5 Hour Charger Gra...
# 74047  221413       206601  3M Tekk Protection White Vented Hard Hat with ...
# 74048  221415       206602  Hy-Lite Glass Block Fixed Vinyl Windows Driftw...
# 74049  221416       206603  Westinghouse 3 ft. Oil Rubbed Bronze Beaded Ch...
# 74050  221419       206606  BEHR Premium Plus #ICC-101 Florentine Clay Zer...
# 74051  221420       206607  Home Legend Palace Oak Light 3/4 in. Thick x 3...
# 74052  221422       206609  Whitehaus Collection Isabella Wall-Mounted Bat...
# 74053  221423       206610  Champion Power Equipment 6.5 HP Gas-Powered 3 ...
# 74054  221426       206613                    Everbilt 4 in. White Wall Guard
# 74055  221427       206614  Daltile Villa Valleta Calais Springs 18 in. x ...
# 74056  221432       206619  Home Styles Stone Harbor 51 in. Round 7-Piece ...
# 74057  221434       206621  Crown Bolt M6-32 x 90 mm. Internal Hex Socket ...
# 74058  221443       206627           25 in. Stainless Tip-Out Sink Front Tray
# 74059  221449       206631  Masonite New Haven Three Quarter Oval Lite Pri...
# 74060  221450       206632  Lilly Miller UltraGreen 1 Gal. Vitamin B-1 Pla...
# 74061  221455       206637  Schluter Rondec Stainless Steel 3/8 in. x 1 in...
# 74062  221457       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063  221458       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064  221463       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065  221471       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066  221473       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                                       search_term  relevance
# 0                                   angle bracket       3.00
# 1                                       l bracket       2.50
# 2                                       deck over       3.00
# 3                                rain shower head       2.33
# 4                              shower only faucet       2.67
# 5                                  convection otr       3.00
# 6                            microwave over stove       2.67
# 7                                      microwaves       3.00
# 8                                 emergency light       2.67
# 9                                         mdf 3/4       3.00
# 10                                   steele stake       2.67
# 11                 briggs and stratton lawn mower       3.00
# 12                                       gas mowe       3.00
# 13                                    honda mower       2.00
# 14             hampton bay chestnut pull up shade       2.67
# 15                                       disposer       2.67
# 16                                   grill gazebo       3.00
# 17                                    door guards       1.00
# 18                         metal plate cover gcfi       1.67
# 19                                 radiator grate       2.33
# 20                                windows screens       2.33
# 21                       1x1 rail decorative wood       1.33
# 22                         4*8 beadboard paneling       2.67
# 23                               4x8wood paneling       2.33
# 24                                        MDF 4x8       1.33
# 25                            wainscot chair rail       2.33
# 26                        wainscot plank paneling       2.33
# 27                                 lawn sprkinler       2.00
# 28                             rainbird sprinkler       2.33
# 29                           PLATFORM FOR WASHERS       2.67
# ...                                           ...        ...
# 74037                plastic 3 piece nativity set       1.67
# 74038                  pass through curtain rings       1.33
# 74039                crosley lafayette kf30024bwh       2.33
# 74040                            dremel auto rust       2.33
# 74041                   privacy glass pivot doors       2.67
# 74042                alabaster blinds 39x72 alvin       1.67
# 74043       exterior shutter with movable louvers       3.00
# 74044                                 lightsensor       2.67
# 74045                      bypass 12 water filter       1.33
# 74046                                     ni-2.4v       2.00
# 74047                        hard hat with mining       1.67
# 74048    replace a broken glass in a vinyl window       2.00
# 74049                 ceiling fan with chain cord       1.00
# 74050                             florentine clay       2.33
# 74051                          trim a home lights       2.00
# 74052                     whitehaus bathroom sinl       2.33
# 74053                        6.5 hp gas generator       2.33
# 74054                      splash guard for  wall       2.00
# 74055                spicewood springs floor tile       1.67
# 74056                        laguna porcelin tile       2.00
# 74057                               m6 screw 90mm       2.67
# 74058                           sink tip-out tray       3.00
# 74059          fiberglass front doors by masonite       3.00
# 74060                          starter fertillzer       2.00
# 74061  rondec stainless steel 3/8 edge protection       3.00
# 74062                              tv riser glass       1.00
# 74063                           r20 halogen light       3.00
# 74064     schlage lock siena half dummy knob with       2.33
# 74065                           zen garden  decor       3.00
# 74066                fine sheer curtain 63 inches       2.33
#
# [74067 rows x 5 columns]

# %%
df_test
# Out:
#             id  product_uid  \
# 0            1       100001
# 1            4       100001
# 2            5       100001
# 3            6       100001
# 4            7       100001
# 5            8       100001
# 6           10       100003
# 7           11       100003
# 8           12       100003
# 9           13       100004
# 10          14       100005
# 11          15       100005
# 12          19       100006
# 13          22       100006
# 14          24       100008
# 15          25       100009
# 16          26       100009
# 17          28       100010
# 18          29       100010
# 19          30       100010
# 20          31       100010
# 21          32       100010
# 22          33       100010
# 23          36       100011
# 24          39       100011
# 25          40       100011
# 26          41       100011
# 27          42       100011
# 28          43       100011
# 29          44       100011
# ...        ...          ...
# 166663  240731       224399
# 166664  240732       224400
# 166665  240733       224401
# 166666  240734       224402
# 166667  240735       224403
# 166668  240736       224404
# 166669  240737       224405
# 166670  240738       224406
# 166671  240739       224407
# 166672  240740       224408
# 166673  240741       224409
# 166674  240742       224410
# 166675  240743       224411
# 166676  240744       224412
# 166677  240745       224413
# 166678  240746       224414
# 166679  240747       224415
# 166680  240748       224416
# 166681  240749       224417
# 166682  240750       224418
# 166683  240751       224419
# 166684  240752       224420
# 166685  240753       224421
# 166686  240754       224422
# 166687  240755       224423
# 166688  240756       224424
# 166689  240757       224425
# 166690  240758       224426
# 166691  240759       224427
# 166692  240760       224428
#
#                                             product_title  \
# 0                       Simpson Strong-Tie 12-Gauge Angle
# 1                       Simpson Strong-Tie 12-Gauge Angle
# 2                       Simpson Strong-Tie 12-Gauge Angle
# 3                       Simpson Strong-Tie 12-Gauge Angle
# 4                       Simpson Strong-Tie 12-Gauge Angle
# 5                       Simpson Strong-Tie 12-Gauge Angle
# 6       STERLING Ensemble 33-1/4 in. x 60 in. x 75-1/4...
# 7       STERLING Ensemble 33-1/4 in. x 60 in. x 75-1/4...
# 8       STERLING Ensemble 33-1/4 in. x 60 in. x 75-1/4...
# 9       Grape Solar 265-Watt Polycrystalline Solar Pan...
# 10      Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 11      Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 12      Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 13      Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 14      Teks #10 1-1/2 in. External Hex Flange Hex-Hea...
# 15      House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 16      House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 17           Valley View Industries Metal Stakes (4-Pack)
# 18           Valley View Industries Metal Stakes (4-Pack)
# 19           Valley View Industries Metal Stakes (4-Pack)
# 20           Valley View Industries Metal Stakes (4-Pack)
# 21           Valley View Industries Metal Stakes (4-Pack)
# 22           Valley View Industries Metal Stakes (4-Pack)
# 23      Toro Personal Pace Recycler 22 in. Variable Sp...
# 24      Toro Personal Pace Recycler 22 in. Variable Sp...
# 25      Toro Personal Pace Recycler 22 in. Variable Sp...
# 26      Toro Personal Pace Recycler 22 in. Variable Sp...
# 27      Toro Personal Pace Recycler 22 in. Variable Sp...
# 28      Toro Personal Pace Recycler 22 in. Variable Sp...
# 29      Toro Personal Pace Recycler 22 in. Variable Sp...
# ...                                                   ...
# 166663                      6-Panel Composite Bifold Door
# 166664     Eaton CSR 200-Amp Double Pole Main Breaker Kit
# 166665  Crown Bolt 3/16 in. Zinc Plated Steel Axle Hat...
# 166666              Dickies 2-Pocket Utility Knife Sheath
# 166667  Patio Living Concepts San Juan 60 in. Outdoor ...
# 166668             Speakman Emergency Eyewash Safety Sign
# 166669      Plantronics Cable for M12 and CS50/CS55 Phone
# 166670  Glomar Vanguard 9-Light Textured Black Chandel...
# 166671        Kwikset Milan Satin Nickel Half-Dummy Lever
# 166672  Advanced Drainage Systems 1/2 in. x 100 ft. IP...
# 166673  Magnavox 50 in. Class LED 1080p 120 BMR Slim HDTV
# 166674  Ekena Millwork 7 in. x 3/4 in. x 11 in. Hillsb...
# 166675  Minwax 1 gal. Semi-Gloss Polycrylic Protective...
# 166676  Southern Living Plant Collection 3 Gal. Pink S...
# 166677  GE 5.0 cu. ft. Gas Range with Self-Cleaning Ov...
# 166678  Southwire 150 ft. 12-3 CU W/G Submersible Pump...
# 166679  Generac Protector Series 15,000-Watt 120/240-V...
# 166680  KOHLER Clearflo Brass Toe Tap Bath Drain in Vi...
# 166681  Casablanca 4-Light Maiden Bronze Ceiling Fan F...
# 166682  Glidden Premium 5-gal. #HDGR19 Fresh Peonies S...
# 166683  Everbilt 1/8 in. x 50 ft. Reflective Black Par...
# 166684  Crown Bolt 5/16 in. (1/4 in.-20) x 1-1/2 in. A...
# 166685  Universal Tubs 4.5 ft. Right Drain Wheel Chair...
# 166686  Everbilt #12 x 1-1/2 in. Phillips Brass Flat-H...
# 166687  Coastal Shower Doors Legend Series 24 in. x 64...
# 166688  stufurhome Norma 24 in. W x 16 in. D x 34 in. ...
# 166689  Home Decorators Collection 49 in. D Alessandro...
# 166690  Simpson Strong-Tie HB 3-1/2 x 14 in. Top Flang...
# 166691  1/4 in. -20 tpi x 1-1/2 in. Stainless Steel Bu...
# 166692                      Bosch 4 in. Bi-Metal Hole Saw
#
#                            search_term
# 0                    90 degree bracket
# 1                     metal l brackets
# 2                     simpson sku able
# 3                 simpson strong  ties
# 4            simpson strong tie hcc668
# 5                      wood connectors
# 6                  bath and shower kit
# 7                       bath drain kit
# 8                 one piece tub shower
# 9                          solar panel
# 10      1 handle shower delta trim kit
# 11         delta ashland shower faucet
# 12                       cooking stove
# 13               microwaves over range
# 14                 self tapping screws
# 15                   3 1/20door casing
# 16                           door trim
# 17                       anchor stakes
# 18                    landscape edging
# 19                         lawn edging
# 20                        metal stakes
# 21                              stakes
# 22              steel landscape edging
# 23            electric start gas mower
# 24                   honda push mowers
# 25                        lawn  mowers
# 26                          Lawnmowers
# 27                          push mower
# 28          self propelled lawn mowers
# 29                       toro lawn moa
# ...                                ...
# 166663        bifold oak 6 panel doors
# 166664     200 amp breaker double pole
# 166665               axle locking nuts
# 166666                          sheath
# 166667            outdoor patio shades
# 166668                    safety signs
# 166669                     phone cable
# 166670                        vanguard
# 166671                    dummy handle
# 166672       Advanced drainage systems
# 166673                         led tvs
# 166674                       l molding
# 166675               minwax polycrylic
# 166676                       camellias
# 166677                black gas ranges
# 166678                submersible wire
# 166679   32kw generac protector series
# 166680                   bathroom taps
# 166681      ceiling fan light fixtures
# 166682                         Peonies
# 166683                        paracord
# 166684            2 inch  1/4-20 bolts
# 166685                     bath chairs
# 166686                       1/2 brass
# 166687              pivot shower doors
# 166688        24 whtie storage cabinet
# 166689               adirondeck cusion
# 166690                              hb
# 166691                     hex sockets
# 166692                 4 inch hole saw
#
# [166693 rows x 4 columns]

# %% [markdown]
# #s

# %%
stemmer.stem("testing")
# Out:
# u'test'

# %%
Tester = "this is the best winning"
Tester.split()
# Out:
# ['this', 'is', 'the', 'best', 'winning']

# %%
" ".join([stemmer.stem(word) for word in Tester.split()])
# Out:
# u'this is the best win'

# %%
Tester
# Out:
# 'this is the best winning'

# %%
def str_stemmer(s):
	return " ".join([stemmer.stem(word) for word in s.lower().split()])

def str_common_word(str1, str2):
	return sum(int(str2.find(word)>=0) for word in str1.split())

# %%
df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)

df_all = pd.merge(df_all, df_pro_desc, how='left', on='product_uid')

df_all_original = df_all

# %%
df_all['search_term'] = df_all['search_term'].map(lambda x:str_stemmer(x))
df_all['product_title'] = df_all['product_title'].map(lambda x:str_stemmer(x))
df_all['product_description'] = df_all['product_description'].map(lambda x:str_stemmer(x))

# %%
df_all['len_of_query'] = df_all['search_term'].map(lambda x:len(x.split())).astype(np.int64)

# %%
df_all['product_info'] = df_all['search_term']+"\t"+df_all['product_title']+"\t"+df_all['product_description']

# %%
df_all['word_in_title'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))

# %%
df_all['word_in_description'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[2]))

# %%
df_all_save = df_all

# %%
df_train = df_all.iloc[:num_train]
df_test = df_all.iloc[num_train:]
id_test = df_test['id']

# %%
y_train = df_train['relevance'].values
X_train = df_train.drop(['id','relevance'],axis=1).values
X_test = df_test.drop(['id','relevance'],axis=1).values

# %%
rf = RandomForestRegressor(n_estimators=15, max_depth=6, random_state=0)
clf = BaggingRegressor(rf, n_estimators=45, max_samples=0.1, random_state=25)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-f6e225ef188c> in <module>()
#       1 rf = RandomForestRegressor(n_estimators=15, max_depth=6, random_state=0)
#       2 clf = BaggingRegressor(rf, n_estimators=45, max_samples=0.1, random_state=25)
# ----> 3 clf.fit(X_train, y_train)
#       4 y_pred = clf.predict(X_test)
#
# C:\Users\Joe\Anaconda2\lib\site-packages\sklearn\ensemble\bagging.py in fit(self, X, y, sample_weight)
#     261
#     262         # Convert data
# --> 263         X, y = check_X_y(X, y, ['csr', 'csc'])
#     264
#     265         # Remap output
#
# C:\Users\Joe\Anaconda2\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     508     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     509                     ensure_2d, allow_nd, ensure_min_samples,
# --> 510                     ensure_min_features, warn_on_dtype, estimator)
#     511     if multi_output:
#     512         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\Users\Joe\Anaconda2\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     371                                       force_all_finite)
#     372     else:
# --> 373         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     374
#     375         if ensure_2d:
#
# ValueError: could not convert string to float: fine sheer curtain 63 inch lichtenberg pool blue no. 918 millenni ryan heather textur sheer curtain panel, 40 in. w x 63 in. l no. 918 millenni ryan heather textur semi-sh curtain is a casual solid th

# %%
df_train.drop(['id','relevance'],axis=1)

# %%
X_test
